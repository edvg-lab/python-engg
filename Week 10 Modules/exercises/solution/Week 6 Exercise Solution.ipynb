# %% [markdown]
# # `circle` Module
#
# ### I. Create a `circle` module that implements the following:
#
# 1. `calculate_diameter(radius)` - given a particular radius, calculate and return the diameter of a circle
# 2. `calculate_radius(diameter)` - given a particular diameter, calculate and return the radius of a circle
# 3. `calculate_circumference(diameter)` - given a particular diameter, calculate and return the circumference of a circle
# 4. `calculate_area(radius)` - given a particular radius, calculate and return the area of a circle
# 5. `PI` - store the value of PI in a variable `PI` inside the `circle` module, return it from the module and print out if the user asks for it
#
# ### II. include your `circle` module in the same directory as this notebook and create a simple program that asks the user for a choice and a radius/diameter that uses the module:
#
# Sample Menu:
# ```
# Welcome to this simple circle calculator.
# Menu:
# 1. calculate the diameter
# 2. calculate the radius
# 3. calculate the circumference
# 4. calculate the area
# 5. get the value of PI
#
# What do you want to do?
# ```
#
# #### Case 1: calculate the diameter
# ```
# What do you want to do? 1
# Enter radius: 16
# Given radius 16, the diameter of the circle is 32
# ```
#
# #### Case 2: calculate the radius
# ```
# What do you want to do? 2
# Enter diameter: 32
# Given diameter 32, the radius of the circle is 16
# ```
#
# #### Case 3: calculate the circumference
# ```
# What do you want to do? 3
# Enter diameter: 32
# Given diameter 32, the circumference of the circle is 100.53096491487338
# ```
#
# #### Case 4: calculate the area
# ```
# What do you want to do? 4
# Enter radius: 16
# Given radius 16, the area of the circle is 804.247719318987
# ```
#
# #### Case 5: get the value of PI
# ```
# What do you want to do? 5
# The value of PI is 3.141592653589793
# ```
#
# ##### HINTS:
# 1. implement items 1-4 as functions inside `circle.py`
# 2. implement item 5 as a variable
# 3. use the `import` statement or any of its variations as discussed in the webinar to include `circle` module for use in the notebook
# 4. the `input` function will be of great use for getting user input
# 5. conditional statements such as `if`, `elif` and `else` are encouraged
# 6. the `math` module has a PI constant you can use
#
# ## Submit both `circle.py` and this notebook in your assignment submission bin
#
# #### Formula References:
# http://www.math.com/tables/geometry/circles.htm

# %%
# import module here
import circle

# Implement menu here
menu_lines = [
    "Welcome to this simple circle calculator.",
    "Menu:",
    "1. calculate the diameter",
    "2. calculate the radius",
    "3. calculate the circumference",
    "4. calculate the area",
    "5. get the value of PI"
]
for menu_item in menu_lines:
    print(menu_item)
    
choice = input("What do you want to do? ")

if choice == '1':
    radius = float(input("Enter radius: "))
    diameter = circle.calculate_diameter(radius)
    print("Given radius "+str(radius)+" , the diameter of the circle is "+str(diameter))
elif choice == '2':
    diameter = float(input("Enter diameter: "))
    radius = circle.calculate_radius(diameter)
    print("Given diameter "+str(diameter)+" , the radius of the circle is "+str(radius))
elif choice == '3':
    diameter = float(input("Enter diameter: "))
    circumference = circle.calculate_circumference(diameter)
    print("Given diameter "+str(diameter)+" , the circumference of the circle is "+str(circumference))
elif choice == '4':
    radius = float(input("Enter radius: "))
    area = circle.calculate_area(radius)
    print("Given radius "+str(radius)+" , the area of the circle is "+str(area))
elif choice == '5':
    print("The value of PI is "+str(circle.PI))
# Out:
# Welcome to this simple circle calculator.
# Menu:
# 1. calculate the diameter
# 2. calculate the radius
# 3. calculate the circumference
# 4. calculate the area
# 5. get the value of PI
# What do you want to do? 1
# Enter radius: 8
# Given radius 8.0 , the diameter of the circle is 16.0
# Enter diameter: 16
# Given diameter 16.0 , the radius of the circle is 8.0
