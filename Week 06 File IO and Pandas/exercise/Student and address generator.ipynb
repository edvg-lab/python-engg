# %% [markdown]
# ## Student CSV Generator

# %%
# install faker package if not yet installed
# !pip install faker
# Out:
# Requirement already satisfied: faker in /anaconda3/lib/python3.7/site-packages (1.0.7)
# Requirement already satisfied: text-unidecode==1.2 in /anaconda3/lib/python3.7/site-packages (from faker) (1.2)
# Requirement already satisfied: six>=1.10 in /anaconda3/lib/python3.7/site-packages (from faker) (1.11.0)
# Requirement already satisfied: python-dateutil>=2.4 in /anaconda3/lib/python3.7/site-packages (from faker) (2.7.3)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# indeed 0.0.4 has requirement requests==2.0.0, but you'll have requests 2.20.1 which is incompatible.
# You are using pip version 10.0.1, however version 19.2.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# inport faker, numpy and pandas
from faker import Faker
import numpy as np
import pandas as pd

# %%
# create a list of majors specializations separated by '_' (underscore)
major_spec = [
    'engineering_civil',
    'engineering_mechanical',
    'engineering_chemical',
    'engineering_industrial',
    'engineering_mechatronics',
    'engineering_civil',
    'engineering_computer',
    'engineering_electronics',
    'engineering_electrical',
    'artificial-intelligence_natural-language-processing',
    'artificial-intelligence_robotics',
    'artificial-intelligence_expert-systems',
    'artificial-intelligence_machile-learning',
    'artificial-intelligence_computer-vision'
]
# create a faker object, this generates fake data
fake = Faker()

# %%
# create a student dataframe
student_df = pd.DataFrame({
    # using list comprehension to efficiently generate a list of 100 student_ids 
    'student_id': ['2019-'+str(id) for id in np.arange(1,101)], 
    # using list comprehension to efficiently generate a list of 100 fake student names
    'name': [fake.name() for x in np.arange(100)],
    # using numpy's choice function to get 100 random major_specializations for the fake students students
    'major_spec': np.random.choice(major_spec,size=100),
    # for Q1 to Q4, generate random integers in between 70 to 100, with size of 100
    'Q1': np.random.randint(70,100,100),
    'Q2': np.random.randint(70,100,100),
    'Q3': np.random.randint(70,100,100),
    'Q4': np.random.randint(70,100,100),
})
# print out dataframe (only works in a jupyter notebook)
student_df
# Out:
#    student_id                    name  \
# 0      2019-1           Jeremy Morgan
# 1      2019-2            David Hoover
# 2      2019-3           Vincent Lynch
# 3      2019-4           Frank Simpson
# 4      2019-5              John Mason
# 5      2019-6            Joseph Smith
# 6      2019-7        Melissa Faulkner
# 7      2019-8            Emily Nguyen
# 8      2019-9              Tony Scott
# 9     2019-10             Donna Moore
# 10    2019-11     Jacqueline Arellano
# 11    2019-12            Jason Rogers
# 12    2019-13          Erica Mitchell
# 13    2019-14            Brenda Brown
# 14    2019-15         Kimberly Brooks
# 15    2019-16            Kyle Johnson
# 16    2019-17            Karen Ramsey
# 17    2019-18        Joshua Schneider
# 18    2019-19      Christopher Nelson
# 19    2019-20           George Harris
# 20    2019-21         Amanda Thompson
# 21    2019-22      Mr. Ryan Hanson MD
# 22    2019-23         Nicholas Lester
# 23    2019-24           Kenneth Davis
# 24    2019-25      Stephen Russell II
# 25    2019-26         Richard Nichols
# 75                             engineering_mechanical  93  84  82  83
# 76  artificial-intelligence_natural-language-proce...  81  80  73  97
# 77                                  engineering_civil  96  83  77  82
# 78             artificial-intelligence_expert-systems  77  94  94  79
# 79                             engineering_mechanical  92  90  78  83
# 80  artificial-intelligence_natural-language-proce...  84  80  77  80
# 81                                  engineering_civil  91  72  93  75
# 82                             engineering_industrial  75  85  94  97
# 83                               engineering_computer  97  95  89  99
# 84                               engineering_chemical  70  84  75  71
# 85                                  engineering_civil  95  91  85  98
# 86                            engineering_electronics  94  92  73  76
# 87                            engineering_electronics  71  77  83  91
# 88                             engineering_mechanical  81  98  88  89
# 89                               engineering_chemical  90  96  90  97
# 90                             engineering_mechanical  78  73  95  72
# 91                             engineering_mechanical  83  89  98  94
# 92                             engineering_industrial  77  82  90  79
# 93                            engineering_electronics  93  83  86  94
# 94             artificial-intelligence_expert-systems  83  81  88  76
# 95           artificial-intelligence_machile-learning  99  91  74  80
# 96                   artificial-intelligence_robotics  88  91  98  74
# 97            artificial-intelligence_computer-vision  83  88  91  71
# 98                               engineering_chemical  83  91  82  75
# 99  artificial-intelligence_natural-language-proce...  83  95  77  87
#
# [100 rows x 7 columns]

# %%
# save to students.csv
student_df.to_csv('students.csv',index=False)

# %%
# load students.csv into a new dataframe to check that all rows and columns were saved successfully
test_student_df = pd.read_csv('students.csv')
test_student_df
# Out:
#    student_id                 name  \
# 0      2019-1           John Smith
# 1      2019-2      Amanda Anderson
# 2      2019-3  Dominique Schneider
# 3      2019-4        Kyle Campbell
# 4      2019-5  Stephanie Gutierrez
# 5      2019-6        Gerald Jacobs
# 6      2019-7       Kevin Marshall
# 7      2019-8        Paul Williams
# 8      2019-9      Gabriel Vaughan
# 9     2019-10    Jonathan Cantrell
# 10    2019-11          Ruben Smith
# 11    2019-12         Wanda Bowman
# 12    2019-13     Alicia Hernandez
# 13    2019-14            Cody Pope
# 14    2019-15         Donna Wilson
# 15    2019-16     Brandon Clements
# 16    2019-17         Kayla Gamble
# 17    2019-18         Ryan Schmidt
# 18    2019-19        Jessica Jones
# 19    2019-20    Shirley Wilkinson
# 20    2019-21         Amber Martin
# 21    2019-22      Jennifer Cooper
# 22    2019-23      Steve Mcfarland
# 23    2019-24         Adam Sanchez
# 24    2019-25         Manuel Jones
# 25    2019-26      Elizabeth Irwin
# 26    2019-27        Robert Duncan
# 27    2019-28         Laura Malone
# 28    2019-29        Morgan Cortez
# 29    2019-30        Taylor Watson
# ..        ...                  ...
# 70    2019-71        Paul Mccarthy
# 71    2019-72      Rachael Stevens
# 72    2019-73       Patricia Solis
# 73    2019-74        Benjamin Bray
# 74    2019-75   Kristin Richardson
# 75    2019-76     Nicholas Johnson
# 76    2019-77      Angelica Walker
# 77    2019-78      Stephanie Ramos
# 78    2019-79         Jeremy Roman
# 79    2019-80        Kaylee Morgan
# 80    2019-81       Megan Martinez
# 86                           engineering_mechatronics  72  78  87  99
# 87                             engineering_mechanical  85  77  93  78
# 88             artificial-intelligence_expert-systems  75  99  93  78
# 89                   artificial-intelligence_robotics  82  98  90  82
# 90                             engineering_electrical  86  78  84  98
# 91                               engineering_computer  77  78  95  95
# 92                                  engineering_civil  87  99  91  93
# 93            artificial-intelligence_computer-vision  76  73  87  97
# 94                             engineering_industrial  76  76  78  81
# 95                             engineering_industrial  92  77  87  82
# 96           artificial-intelligence_machile-learning  86  98  77  84
# 97                               engineering_chemical  83  75  97  92
# 98  artificial-intelligence_natural-language-proce...  98  96  97  76
# 99           artificial-intelligence_machile-learning  97  93  70  96
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Address Traffic Data Generator

# %%
columns =['id','address','type','W1','W2','W3','W4']
address_df = pd.DataFrame(columns=columns)

for x in range(1,51):
    address = fake.address().replace('\n',',')
    for week in range(1,5):
        peak_data = {
            'id': x,
            'address': address,
            'type': 'peak',
            'W'+str(week): np.random.randint(0,24),
        }
        address_df = address_df.append(peak_data,ignore_index=True)
        offpeak_data = {
            'id': x,
            'address': address,
            'type': 'off-peak',
            'W'+str(week): np.random.randint(0,24),
        }
        address_df = address_df.append(offpeak_data,ignore_index=True)

address_df
# Out:
#      id                                            address      type   W1  \
# 0     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050      peak    0
# 1     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050  off-peak   23
# 2     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050      peak  NaN
# 3     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050  off-peak  NaN
# 4     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050      peak  NaN
# 5     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050  off-peak  NaN
# 6     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050      peak  NaN
# 7     1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050  off-peak  NaN
# 8     2     9384 Kane Fort Suite 285,South Kayla, CO 48729      peak   15
# 9     2     9384 Kane Fort Suite 285,South Kayla, CO 48729  off-peak   21
# 10    2     9384 Kane Fort Suite 285,South Kayla, CO 48729      peak  NaN
# 11    2     9384 Kane Fort Suite 285,South Kayla, CO 48729  off-peak  NaN
# 12    2     9384 Kane Fort Suite 285,South Kayla, CO 48729      peak  NaN
# 13    2     9384 Kane Fort Suite 285,South Kayla, CO 48729  off-peak  NaN
# 14    2     9384 Kane Fort Suite 285,South Kayla, CO 48729      peak  NaN
# 15    2     9384 Kane Fort Suite 285,South Kayla, CO 48729  off-peak  NaN
# 16    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...      peak    9
# 17    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...  off-peak    2
# 18    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...      peak  NaN
# 19    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...  off-peak  NaN
# 20    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...      peak  NaN
# 21    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...  off-peak  NaN
# 22    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...      peak  NaN
# 23    3  02857 Kathleen Divide Suite 570,Wandaside, VT ...  off-peak  NaN
# 24    4                 86632 Hood Rest,Hoodfurt, MA 19210      peak    7
# 25    4                 86632 Hood Rest,Hoodfurt, MA 19210  off-peak   11
# 26    4                 86632 Hood Rest,Hoodfurt, MA 19210      peak  NaN
# 27    4                 86632 Hood Rest,Hoodfurt, MA 19210  off-peak  NaN
# 28    4                 86632 Hood Rest,Hoodfurt, MA 19210      peak  NaN
# 29    4                 86632 Hood Rest,Hoodfurt, MA 19210  off-peak  NaN
# ..   ..                                                ...       ...  ...
# 370  47                    Unit 4810 Box 2163,DPO AE 49284      peak  NaN
# 371  47                    Unit 4810 Box 2163,DPO AE 49284  off-peak  NaN
# 372  47                    Unit 4810 Box 2163,DPO AE 49284      peak  NaN
# 373  47                    Unit 4810 Box 2163,DPO AE 49284  off-peak  NaN
# 374  47                    Unit 4810 Box 2163,DPO AE 49284      peak  NaN
# 375  47                    Unit 4810 Box 2163,DPO AE 49284  off-peak  NaN
# 376  48  40401 Matthew Summit Suite 232,New Melissa, AZ...      peak    4
# 377  48  40401 Matthew Summit Suite 232,New Melissa, AZ...  off-peak   22
# 378  48  40401 Matthew Summit Suite 232,New Melissa, AZ...      peak  NaN
# 379  48  40401 Matthew Summit Suite 232,New Melissa, AZ...  off-peak  NaN
# 380  48  40401 Matthew Summit Suite 232,New Melissa, AZ...      peak  NaN
# 381  48  40401 Matthew Summit Suite 232,New Melissa, AZ...  off-peak  NaN
# 382  48  40401 Matthew Summit Suite 232,New Melissa, AZ...      peak  NaN
# 383  48  40401 Matthew Summit Suite 232,New Melissa, AZ...  off-peak  NaN
# 384  49           3332 Henson Passage,Millerland, MO 39230      peak   13
# 385  49           3332 Henson Passage,Millerland, MO 39230  off-peak   20
# 386  49           3332 Henson Passage,Millerland, MO 39230      peak  NaN
# 387  49           3332 Henson Passage,Millerland, MO 39230  off-peak  NaN
# 388  49           3332 Henson Passage,Millerland, MO 39230      peak  NaN
# 389  49           3332 Henson Passage,Millerland, MO 39230  off-peak  NaN
# 390  49           3332 Henson Passage,Millerland, MO 39230      peak  NaN
# 391  49           3332 Henson Passage,Millerland, MO 39230  off-peak  NaN
# 392  50                    Unit 4663 Box 7769,DPO AE 62963      peak   11
# 393  50                    Unit 4663 Box 7769,DPO AE 62963  off-peak   10
# 394  50                    Unit 4663 Box 7769,DPO AE 62963      peak  NaN
# 395  50                    Unit 4663 Box 7769,DPO AE 62963  off-peak  NaN
# 396  50                    Unit 4663 Box 7769,DPO AE 62963      peak  NaN
# 397  50                    Unit 4663 Box 7769,DPO AE 62963  off-peak  NaN
# 398  50                    Unit 4663 Box 7769,DPO AE 62963      peak  NaN
# 399  50                    Unit 4663 Box 7769,DPO AE 62963  off-peak  NaN
#
#       W2   W3   W4
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2      4  NaN  NaN
# 3      4  NaN  NaN
# 4    NaN   13  NaN
# 5    NaN   12  NaN
# 6    NaN  NaN   21
# 7    NaN  NaN    5
# 8    NaN  NaN  NaN
# 9    NaN  NaN  NaN
# 10    13  NaN  NaN
# 11     1  NaN  NaN
# 12   NaN   13  NaN
# 13   NaN   15  NaN
# 14   NaN  NaN   15
# 15   NaN  NaN   22
# 16   NaN  NaN  NaN
# 17   NaN  NaN  NaN
# 18     6  NaN  NaN
# 19     1  NaN  NaN
# 20   NaN    3  NaN
# 21   NaN   13  NaN
# 22   NaN  NaN    6
# 23   NaN  NaN   15
# 24   NaN  NaN  NaN
# 25   NaN  NaN  NaN
# 26     9  NaN  NaN
# 27    18  NaN  NaN
# 28   NaN   17  NaN
# 29   NaN   10  NaN
# ..   ...  ...  ...
# 370    7  NaN  NaN
# 371   23  NaN  NaN
# 372  NaN   22  NaN
# 373  NaN   10  NaN
# 374  NaN  NaN   21
# 375  NaN  NaN   15
# 376  NaN  NaN  NaN
# 377  NaN  NaN  NaN
# 378    6  NaN  NaN
# 379   14  NaN  NaN
# 380  NaN   23  NaN
# 381  NaN   23  NaN
# 382  NaN  NaN   17
# 383  NaN  NaN   17
# 384  NaN  NaN  NaN
# 385  NaN  NaN  NaN
# 386   12  NaN  NaN
# 387   12  NaN  NaN
# 388  NaN   16  NaN
# 389  NaN    5  NaN
# 390  NaN  NaN   23
# 391  NaN  NaN   12
# 392  NaN  NaN  NaN
# 393  NaN  NaN  NaN
# 394    5  NaN  NaN
# 395   17  NaN  NaN
# 396  NaN   18  NaN
# 397  NaN    9  NaN
# 398  NaN  NaN    5
# 399  NaN  NaN    7
#
# [400 rows x 7 columns]

# %%
address_melt = pd.melt(address_df,
                       id_vars = ['id','address','type'],
                       var_name = 'week',
                       value_name = 'hour'
)
address_melt.head()
address_melt_clean = address_melt.dropna()
address_melt_clean.head()
# Out:
#    id                                            address      type week hour
# 0   1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050      peak   W1    0
# 1   1      56560 Joyce Canyon,Lake Ronaldmouth, IL 75050  off-peak   W1   23
# 8   2     9384 Kane Fort Suite 285,South Kayla, CO 48729      peak   W1   15
# 9   2     9384 Kane Fort Suite 285,South Kayla, CO 48729  off-peak   W1   21
# 16  3  02857 Kathleen Divide Suite 570,Wandaside, VT ...      peak   W1    9

# %% [markdown]
# address_melt_clean.pivot_table(index=['id','address','week'],
#                                columns="type",
#                                values="hour",
#                                aggfunc=np.mean
#                               )
