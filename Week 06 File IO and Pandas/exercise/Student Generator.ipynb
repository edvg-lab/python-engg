# %% [markdown]
# ## Student CSV Generator

# %%
# install faker package if not yet installed
# !pip install faker
# Out:
# Requirement already satisfied: faker in /anaconda3/lib/python3.7/site-packages (1.0.7)
# Requirement already satisfied: text-unidecode==1.2 in /anaconda3/lib/python3.7/site-packages (from faker) (1.2)
# Requirement already satisfied: python-dateutil>=2.4 in /anaconda3/lib/python3.7/site-packages (from faker) (2.7.3)
# Requirement already satisfied: six>=1.10 in /anaconda3/lib/python3.7/site-packages (from faker) (1.11.0)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# indeed 0.0.4 has requirement requests==2.0.0, but you'll have requests 2.20.1 which is incompatible.
# You are using pip version 10.0.1, however version 19.2.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# inport faker, numpy and pandas
from faker import Faker
import numpy as np
import pandas as pd

# %%
# create a list of majors specializations separated by '_' (underscore)
major_spec = [
    'engineering_civil',
    'engineering_mechanical',
    'engineering_chemical',
    'engineering_industrial',
    'engineering_mechatronics',
    'engineering_civil',
    'engineering_computer',
    'engineering_electronics',
    'engineering_electrical',
    'artificial-intelligence_natural-language-processing',
    'artificial-intelligence_robotics',
    'artificial-intelligence_expert-systems',
    'artificial-intelligence_machile-learning',
    'artificial-intelligence_computer-vision'
]
# create a faker object, this generates fake data
fake = Faker()

# %%
# create a student dataframe using a dictionary
student_df = pd.DataFrame({
    # using list comprehension to efficiently generate a list of 100 student_ids 
    'student_id': ['2019-'+str(id) for id in np.arange(1,101)], 
    # using list comprehension to efficiently generate a list of 100 fake student names
    'name': [fake.name() for x in np.arange(100)],
    # using numpy's choice function to get 100 random major_specializations for the fake students students
    'major_spec': np.random.choice(major_spec,size=100),
    # for Q1 to Q4, generate random integers in between 70 to 100, with size of 100
    'Q1': np.random.randint(70,100,100),
    'Q2': np.random.randint(70,100,100),
    'Q3': np.random.randint(70,100,100),
    'Q4': np.random.randint(70,100,100),
})
# print out dataframe (only works in a jupyter notebook)
student_df
# Out:
#    student_id                     name  \
# 0      2019-1         Hector Henderson
# 1      2019-2         Michael Williams
# 2      2019-3         Michael Mcmillan
# 3      2019-4             Jason Wright
# 4      2019-5              David Dixon
# 5      2019-6           Molly Mcdonald
# 6      2019-7              Mark Harvey
# 7      2019-8           Matthew Wilson
# 8      2019-9             Seth Johnson
# 9     2019-10             Katie Austin
# 10    2019-11      Gabrielle Blackwell
# 11    2019-12           Lori Velasquez
# 12    2019-13      Kristina Arroyo DVM
# 13    2019-14           Mitchell Brown
# 14    2019-15             Brandy Price
# 15    2019-16            William Ramos
# 16    2019-17           Brenda Aguilar
# 17    2019-18              John Bryant
# 18    2019-19           Nicholas Curry
# 19    2019-20             Anthony Page
# 20    2019-21              Brian Brown
# 21    2019-22             Jeremy Smith
# 22    2019-23              Dylan Hayes
# 23    2019-24           Michelle Scott
# 24    2019-25              Penny Lewis
# 25    2019-26           Samantha Downs
# 26    2019-27             Daniel Perez
# 27    2019-28              Rachel Wang
# 28    2019-29             Nancy Wilson
# 29    2019-30           Jonathan Davis
# ..        ...                      ...
# 70    2019-71           Kevin Valencia
# 82                               engineering_computer  86  70  92  70
# 83                               engineering_computer  93  79  87  77
# 84                             engineering_electrical  70  84  99  74
# 85                               engineering_computer  84  87  72  95
# 86                                  engineering_civil  89  98  78  77
# 87             artificial-intelligence_expert-systems  81  85  84  92
# 88                             engineering_electrical  79  87  86  72
# 89            artificial-intelligence_computer-vision  75  92  84  85
# 90             artificial-intelligence_expert-systems  85  70  83  80
# 91                             engineering_mechanical  73  85  73  85
# 92                             engineering_mechanical  72  82  74  99
# 93             artificial-intelligence_expert-systems  71  97  98  72
# 94                            engineering_electronics  72  82  93  81
# 95                             engineering_mechanical  83  81  77  71
# 96            artificial-intelligence_computer-vision  94  94  72  86
# 97                             engineering_mechanical  89  75  76  86
# 98                               engineering_chemical  70  79  73  83
# 99                   artificial-intelligence_robotics  86  84  97  82
#
# [100 rows x 7 columns]

# %%
# save to students.csv
student_df.to_csv('students.csv',index=False)

# %%
# load students.csv into a new dataframe to check that all rows and columns were saved successfully
test_student_df = pd.read_csv('students.csv')
test_student_df
# Out:
#    student_id                     name  \
# 0      2019-1         Hector Henderson
# 1      2019-2         Michael Williams
# 2      2019-3         Michael Mcmillan
# 3      2019-4             Jason Wright
# 4      2019-5              David Dixon
# 5      2019-6           Molly Mcdonald
# 6      2019-7              Mark Harvey
# 7      2019-8           Matthew Wilson
# 8      2019-9             Seth Johnson
# 9     2019-10             Katie Austin
# 10    2019-11      Gabrielle Blackwell
# 11    2019-12           Lori Velasquez
# 12    2019-13      Kristina Arroyo DVM
# 13    2019-14           Mitchell Brown
# 14    2019-15             Brandy Price
# 15    2019-16            William Ramos
# 16    2019-17           Brenda Aguilar
# 17    2019-18              John Bryant
# 18    2019-19           Nicholas Curry
# 19    2019-20             Anthony Page
# 20    2019-21              Brian Brown
# 21    2019-22             Jeremy Smith
# 22    2019-23              Dylan Hayes
# 23    2019-24           Michelle Scott
# 24    2019-25              Penny Lewis
# 25    2019-26           Samantha Downs
# 26    2019-27             Daniel Perez
# 27    2019-28              Rachel Wang
# 28    2019-29             Nancy Wilson
# 29    2019-30           Jonathan Davis
# ..        ...                      ...
# 70    2019-71           Kevin Valencia
# 71    2019-72            Andrew Powell
# 72    2019-73  Jacqueline Williams DVM
# 73    2019-74              James White
# 74    2019-75           Pamela Jackson
# 75    2019-76           Catherine Gray
# 76    2019-77           Michael Carney
# 77    2019-78        Joanne Fitzgerald
# 78    2019-79             Andrew Brown
# 79    2019-80            Alex Williams
# 80    2019-81           Michelle Smith
# 81    2019-82           Anthony George
# 82    2019-83          Shelly Odonnell
# 83    2019-84            Michael Smith
# 84    2019-85           Charlene Moore
# 85    2019-86          Larry Rodriguez
# 86    2019-87              Thomas Reed
# 87    2019-88         Sabrina Martinez
# 88    2019-89              Diana Lopez
# 89    2019-90               Wanda Pena
# 90    2019-91            Shirley Myers
# 91    2019-92            Kelsey Stokes
# 92    2019-93              Mark Harmon
# 93    2019-94           Wanda Castillo
# 94    2019-95         Lorraine Harrell
# 95    2019-96              Penny Owens
